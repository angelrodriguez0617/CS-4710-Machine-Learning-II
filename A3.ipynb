# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import LambdaCallback
import numpy as np

# Test learning rates from 10-100
learning_rates = np.arange(10, 110, 10)

# Initialize an empty dictionary to keep track of learning rates with corresponding losses
learning_loss_dict = {}

# Training data, inputs and outputs for an XOR gate
x_train = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_train = np.array([[0], [1], [1], [0]])

for rate in learning_rates:
    print(f'Training model with learning rate = {rate}')
    # Build the model
    model = Sequential([
        Dense(4, activation='sigmoid', input_shape=(2,)),  # Hidden layer with 4 neurons
        Dense(1, activation='sigmoid')                    # Output layer
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=rate), loss='mse')

    # Define a callback to print results every 10 epochs
    print_callback = LambdaCallback(
        on_epoch_end=lambda epoch, logs: print(f"Epoch {epoch + 1}/{1000} - Loss: {logs['loss']}")
        if (epoch + 1) % 100 == 0 else None
    )

    # Train the model with reduced verbosity and the callback
    model.fit(x_train, y_train, epochs=1000, callbacks=[print_callback], verbose=0)

    # Print the learned weights and biases
    print("\nLearned Weights:")
    for layer in model.layers:
        print(layer.get_weights()[0])

    print("\nLearned Biases:")
    for layer in model.layers:
        print(layer.get_weights()[1])

    # Print the function the model uses to make predictions
    def predict_function(x):
        for i, layer in enumerate(model.layers):
            x = np.dot(x, layer.get_weights()[0]) + layer.get_weights()[1]
            if i < len(model.layers) - 1:
                x = 1 / (1 + np.exp(-x))  # Apply sigmoid activation for hidden layers
        return x

   # Use the function to make predictions
    print("\nPredictions:")
    for input_data in x_train:
        raw_prediction = predict_function(input_data)
        sigmoid_prediction = 1 / (1 + np.exp(-raw_prediction))
        print(f"Input: {input_data}, Raw Prediction: {raw_prediction}, Sigmoid Prediction: {sigmoid_prediction}")

    # Evaluate the model on the training data
    loss = model.evaluate(x_train, y_train)
    learning_loss_dict[rate] = loss
    print(f'Final Loss: {loss}')
    print('\n--------------------------------------------------------------------------------------------\n')

min_key = min(learning_loss_dict, key=learning_loss_dict.get)
print(f'The minimum loss is {learning_loss_dict[min_key]} which came from a learning rate of {min_key}\n')
# Out:
# Training model with learning rate = 10
# Epoch 100/1000 - Loss: 0.019687717780470848
# Epoch 200/1000 - Loss: 0.002889110241085291
# Epoch 300/1000 - Loss: 0.001430297619663179
# Epoch 400/1000 - Loss: 0.0009330266038887203
# Epoch 500/1000 - Loss: 0.0006872353842481971
# Epoch 600/1000 - Loss: 0.0005418839282356203
# Epoch 700/1000 - Loss: 0.0004462829092517495
# Epoch 800/1000 - Loss: 0.00037880486343055964
# Epoch 900/1000 - Loss: 0.0003287234576418996
# Epoch 1000/1000 - Loss: 0.0002901288971770555
#
# Learned Weights:
# [[-4.1174264  -6.8579016  -3.839611   -0.98412955]
#  [ 1.853677   -6.2294426  -5.22525    -0.6912949 ]]
# [[  3.1102986]
#  [-10.267457 ]
#  [  9.211193 ]
#  [  0.6185799]]
#
# Learned Biases:
# [-1.2548654  2.6723957  6.583116  -0.6234467]
# [-4.716341]
#
# Predictions:
# Input: [0 0], Raw Prediction: [-4.2158966], Sigmoid Prediction: [0.01454442]
# Input: [0 1], Raw Prediction: [4.46391054], Sigmoid Prediction: [0.9886139]
# Input: [1 0], Raw Prediction: [3.90175322], Sigmoid Prediction: [0.98019376]
# Input: [1 1], Raw Prediction: [-3.86006325], Sigmoid Prediction: [0.02063202]
# 1/1 [==============================] - 0s 240ms/step - loss: 2.8979e-04
# Final Loss: 0.00028978788759559393
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 20
# Epoch 100/1000 - Loss: 0.0022153223399072886
# Epoch 200/1000 - Loss: 0.0008325967937707901
# Epoch 300/1000 - Loss: 0.0005029762396588922
# Epoch 400/1000 - Loss: 0.000357727927621454
# Epoch 500/1000 - Loss: 0.0002765441022347659
# Epoch 600/1000 - Loss: 0.0002248940581921488
# Epoch 700/1000 - Loss: 0.00018922427261713892
# Epoch 800/1000 - Loss: 0.000163154662004672
# Epoch 900/1000 - Loss: 0.0001432893332093954
# Epoch 1000/1000 - Loss: 0.0001276627299375832
#
# Learned Weights:
# [[ 2.1959295   6.618101   -0.19496946 -6.666599  ]
#  [-2.3989165  -6.9268584  -1.0763285   6.382052  ]]
# [[ 1.626901  ]
#  [ 9.289277  ]
#  [-0.53458387]
#  [ 9.996936  ]]
#
# Learned Biases:
# [-2.188546  -3.6613019 -2.0417073 -3.4455771]
# [-5.0057793]
#
# Predictions:
# Input: [0 0], Raw Prediction: [-4.36157416], Sigmoid Prediction: [0.01259756]
# Input: [0 1], Raw Prediction: [4.48149139], Sigmoid Prediction: [0.98881011]
# Input: [1 0], Raw Prediction: [4.58972689], Sigmoid Prediction: [0.98994647]
# Input: [1 1], Raw Prediction: [-4.48192062], Sigmoid Prediction: [0.01118514]
# 1/1 [==============================] - 0s 138ms/step - loss: 1.2752e-04
# Final Loss: 0.00012752316251862794
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 30
# Epoch 100/1000 - Loss: 0.0037518355529755354
# Epoch 200/1000 - Loss: 0.0007522786618210375
# Epoch 300/1000 - Loss: 0.00040988207911141217
# Epoch 400/1000 - Loss: 0.0002795452019199729
# Epoch 500/1000 - Loss: 0.0002113454684149474
# Epoch 600/1000 - Loss: 0.0001695558021310717
# Epoch 700/1000 - Loss: 0.00014138562255539
# Epoch 800/1000 - Loss: 0.00012113762932131067
# Epoch 900/1000 - Loss: 0.00010589799785520881
# Epoch 1000/1000 - Loss: 9.40209865802899e-05
#
# Learned Weights:
# [[-5.868558   5.2035565 -7.639291  -0.9851191]
#  [-6.782996  -7.669676   3.7477453 -1.2981689]]
# [[-6.514001e+00]
#  [ 9.638048e+00]
#  [ 9.602512e+00]
#  [-7.991823e-03]]
#
# Learned Biases:
# [ 1.5386841  -2.0606167  -0.71829545 -2.4937572 ]
# [-4.459602]
#
# Predictions:
# Input: [0 0], Raw Prediction: [-5.58666914], Sigmoid Prediction: [0.0037335]
# Input: [0 1], Raw Prediction: [4.66630951], Sigmoid Prediction: [0.99068074]
# Input: [1 0], Raw Prediction: [4.69706064], Sigmoid Prediction: [0.99096041]
# Input: [1 1], Raw Prediction: [-4.26200115], Sigmoid Prediction: [0.01389819]
# 1/1 [==============================] - 0s 102ms/step - loss: 9.3915e-05
# Final Loss: 9.391526691615582e-05
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 40
# Epoch 100/1000 - Loss: 0.004880526568740606
# Epoch 200/1000 - Loss: 0.0004902287619188428
# Epoch 300/1000 - Loss: 0.00025014730636030436
# Epoch 400/1000 - Loss: 0.00016664424038026482
# Epoch 500/1000 - Loss: 0.0001245270250365138
# Epoch 600/1000 - Loss: 9.922596655087546e-05
# Epoch 700/1000 - Loss: 8.237879228545353e-05
# Epoch 800/1000 - Loss: 7.037038449198008e-05
# Epoch 900/1000 - Loss: 6.138515163911507e-05
# Epoch 1000/1000 - Loss: 5.44135291420389e-05
#
# Learned Weights:
# [[-7.6682324 -8.914869   3.7050498  2.329888 ]
#  [ 3.515695  -9.093973  -6.7345862 -5.103475 ]]
# [[ 10.069994 ]
#  [-12.652419 ]
#  [  6.78018  ]
#  [  4.4462523]]
#
# Learned Biases:
# [-0.17374209  3.0048633  -1.1490746  -0.6719193 ]
# [-4.8608503]
#
# Predictions:
# Input: [0 0], Raw Prediction: [-9.18245481], Sigmoid Prediction: [0.00010282]
# Input: [0 1], Raw Prediction: [4.85284058], Sigmoid Prediction: [0.99225429]
# Input: [1 0], Raw Prediction: [5.13540899], Sigmoid Prediction: [0.99414978]
# Input: [1 1], Raw Prediction: [-4.48979212], Sigmoid Prediction: [0.01109842]
# 1/1 [==============================] - 0s 101ms/step - loss: 5.4351e-05
# Final Loss: 5.4351461585611105e-05
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 50
# Epoch 100/1000 - Loss: 0.1752210259437561
# Epoch 200/1000 - Loss: 0.20484809577465057
# Epoch 300/1000 - Loss: 0.2500913441181183
# Epoch 400/1000 - Loss: 0.2499830275774002
# Epoch 500/1000 - Loss: 0.24961166083812714
# Epoch 600/1000 - Loss: 0.24994339048862457
# Epoch 700/1000 - Loss: 0.24953213334083557
# Epoch 800/1000 - Loss: 0.24998027086257935
# Epoch 900/1000 - Loss: 0.24993284046649933
# Epoch 1000/1000 - Loss: 0.24974364042282104
#
# Learned Weights:
# [[ -2.3339918 -10.568593   -3.253699   -3.0348856]
#  [ -1.3407035 -10.530497   -3.2751205  -3.0189195]]
# [[  4.883037  ]
#  [-14.814928  ]
#  [ -0.5709544 ]
#  [ -0.24416295]]
#
# Learned Biases:
# [ 7.355264   3.8682456 -2.8753772 -2.904756 ]
# [2.7850316]
#
# Predictions:
# Input: [0 0], Raw Prediction: [-6.88991338], Sigmoid Prediction: [0.00101697]
# Input: [0 1], Raw Prediction: [7.6353892], Sigmoid Prediction: [0.99951718]
# Input: [1 0], Raw Prediction: [7.61598108], Sigmoid Prediction: [0.99950773]
# Input: [1 1], Raw Prediction: [7.54792181], Sigmoid Prediction: [0.99947307]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x0000013375F8DD00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 106ms/step - loss: 0.2497
# Final Loss: 0.2497369945049286
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 60
# Epoch 100/1000 - Loss: 0.2410120666027069
# Epoch 200/1000 - Loss: 0.24316228926181793
# Epoch 300/1000 - Loss: 0.0005118879489600658
# Epoch 400/1000 - Loss: 0.0002566128387115896
# Epoch 500/1000 - Loss: 0.00017331799608655274
# Epoch 600/1000 - Loss: 0.00012977857841178775
# Epoch 700/1000 - Loss: 0.00010318416025256738
# Epoch 800/1000 - Loss: 8.535292727174237e-05
# Epoch 900/1000 - Loss: 7.261449354700744e-05
# Epoch 1000/1000 - Loss: 6.308519368758425e-05
#
# Learned Weights:
# [[-10.951306   -5.396791    1.9119647  -7.576128 ]
#  [-11.3950405  -5.5102296  -9.281819    2.6535327]]
# [[-14.490199 ]
#  [ -3.0503283]
#  [  9.784319 ]
#  [ 10.019913 ]]
#
# Learned Biases:
# [ 3.7434406 -1.6209038  1.5851122  0.222825 ]
# [-4.6110625]
#
# Predictions:
# Input: [0 0], Raw Prediction: [-5.5836199], Sigmoid Prediction: [0.00374486]
# Input: [0 1], Raw Prediction: [4.86956259], Sigmoid Prediction: [0.99238176]
# Input: [1 0], Raw Prediction: [4.87859888], Sigmoid Prediction: [0.99244977]
# Input: [1 1], Raw Prediction: [-4.49075486], Sigmoid Prediction: [0.01108786]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x0000013373C86480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 134ms/step - loss: 6.3002e-05
# Final Loss: 6.300208769971505e-05
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 70
# Epoch 100/1000 - Loss: 0.4811924993991852
# Epoch 200/1000 - Loss: 0.49998077750205994
# Epoch 300/1000 - Loss: 0.4999558627605438
# Epoch 400/1000 - Loss: 0.49989989399909973
# Epoch 500/1000 - Loss: 0.4999655783176422
# Epoch 600/1000 - Loss: 0.4999339282512665
# Epoch 700/1000 - Loss: 0.4992583394050598
# Epoch 800/1000 - Loss: 0.4999940097332001
# Epoch 900/1000 - Loss: 0.4999934732913971
# Epoch 1000/1000 - Loss: 0.49999284744262695
#
# Learned Weights:
# [[ -5.0152698   -1.2986298   -0.31293127   1.6198741 ]
#  [ -0.42389452  -1.2910163   -0.06407349 -10.652288  ]]
# [[0.5520904]
#  [3.3425395]
#  [1.3144444]
#  [3.2561803]]
#
# Learned Biases:
# [-5.5331793  7.116703  -3.6133199 -8.459778 ]
# [8.491024]
#
# Predictions:
# Input: [0 0], Raw Prediction: [11.86822695], Sigmoid Prediction: [0.99999299]
# Input: [0 1], Raw Prediction: [11.85757519], Sigmoid Prediction: [0.99999292]
# Input: [1 0], Raw Prediction: [11.85256645], Sigmoid Prediction: [0.99999288]
# Input: [1 1], Raw Prediction: [11.82168623], Sigmoid Prediction: [0.99999266]
# 1/1 [==============================] - 0s 317ms/step - loss: 0.5000
# Final Loss: 0.49999281764030457
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 80
# Epoch 100/1000 - Loss: 0.500099241733551
# Epoch 200/1000 - Loss: 0.5000222325325012
# Epoch 300/1000 - Loss: 0.5000121593475342
# Epoch 400/1000 - Loss: 0.500008225440979
# Epoch 500/1000 - Loss: 0.5000061392784119
# Epoch 600/1000 - Loss: 0.5000048279762268
# Epoch 700/1000 - Loss: 0.5000039339065552
# Epoch 800/1000 - Loss: 0.5000033378601074
# Epoch 900/1000 - Loss: 0.5000028610229492
# Epoch 1000/1000 - Loss: 0.5000025033950806
#
# Learned Weights:
# [[-1.4954596 -2.596464  -8.194282  -3.9078858]
#  [-1.445278  -2.4598737 -8.447217  -3.8992763]]
# [[ -1.0417165]
#  [ -2.2330093]
#  [-13.007724 ]
#  [ -4.209268 ]]
#
# Learned Biases:
# [-2.3025894 -1.023569  13.397537   1.9012874]
# [-5.2443724]
#
# Predictions:
# Input: [0 0], Raw Prediction: [-22.59925482], Sigmoid Prediction: [1.53203376e-10]
# Input: [0 1], Raw Prediction: [-18.75378141], Sigmoid Prediction: [7.16698038e-09]
# Input: [1 0], Raw Prediction: [-18.7608926], Sigmoid Prediction: [7.1161954e-09]
# Input: [1 1], Raw Prediction: [-5.75474549], Sigmoid Prediction: [0.00315771]
# 1/1 [==============================] - 0s 214ms/step - loss: 0.5000
# Final Loss: 0.5000025033950806
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 90
# Epoch 100/1000 - Loss: 0.49999889731407166
# Epoch 200/1000 - Loss: 0.4999988079071045
# Epoch 300/1000 - Loss: 0.4999987781047821
# Epoch 400/1000 - Loss: 0.49999871850013733
# Epoch 500/1000 - Loss: 0.49999862909317017
# Epoch 600/1000 - Loss: 0.499998539686203
# Epoch 700/1000 - Loss: 0.49999842047691345
# Epoch 800/1000 - Loss: 0.4999983012676239
# Epoch 900/1000 - Loss: 0.49999815225601196
# Epoch 1000/1000 - Loss: 0.4999980032444
#
# Learned Weights:
# [[ 0.39869887 -0.9304056   0.48769453 -1.4193577 ]
#  [-0.15102276  0.00518299  0.34304807  0.06390666]]
# [[-4.309694 ]
#  [-3.896428 ]
#  [-4.912276 ]
#  [-3.5776505]]
#
# Learned Biases:
# [-1.5387586e+00 -1.1895607e+00  3.7038582e-04 -1.2984250e+00]
# [-8.162201]
#
# Predictions:
# Input: [0 0], Raw Prediction: [-13.05672394], Sigmoid Prediction: [2.13567868e-06]
# Input: [0 1], Raw Prediction: [-13.42662684], Sigmoid Prediction: [1.47533081e-06]
# Input: [1 0], Raw Prediction: [-12.8895311], Sigmoid Prediction: [2.52433317e-06]
# Input: [1 1], Raw Prediction: [-13.16826823], Sigmoid Prediction: [1.91026202e-06]
# 1/1 [==============================] - 0s 148ms/step - loss: 0.5000
# Final Loss: 0.4999980032444
#
# --------------------------------------------------------------------------------------------
#
# Training model with learning rate = 100
# Epoch 100/1000 - Loss: 0.49999651312828064
# Epoch 200/1000 - Loss: 0.499996155500412
# Epoch 300/1000 - Loss: 0.4999956488609314
# Epoch 400/1000 - Loss: 0.49999502301216125
# Epoch 500/1000 - Loss: 0.4999941885471344
# Epoch 600/1000 - Loss: 0.4999930262565613
# Epoch 700/1000 - Loss: 0.49999120831489563
# Epoch 800/1000 - Loss: 0.4999881982803345
# Epoch 900/1000 - Loss: 0.49998244643211365
# Epoch 1000/1000 - Loss: 0.4999682307243347
#
# Learned Weights:
# [[-1.8281935  -1.1329477  -0.45173216 -1.3493352 ]
#  [ 0.21531133 -1.310047   -0.7282434  -0.2369366 ]]
# [[3.774863 ]
#  [3.8733153]
#  [2.8271487]
#  [4.500137 ]]
#
# Learned Biases:
# [-1.4835271 -2.3668077  0.5375322 -1.9543781]
# [8.478741]
#
# Predictions:
# Input: [0 0], Raw Prediction: [11.85175586], Sigmoid Prediction: [0.99999287]
# Input: [0 1], Raw Prediction: [11.13474817], Sigmoid Prediction: [0.9999854]
# Input: [1 0], Raw Prediction: [10.35875243], Sigmoid Prediction: [0.99996829]
# Input: [1 1], Raw Prediction: [9.77463993], Sigmoid Prediction: [0.99994313]
# 1/1 [==============================] - 0s 92ms/step - loss: 0.5000
# Final Loss: 0.4999679923057556
#
# --------------------------------------------------------------------------------------------
#
# The minimum loss is 5.4351461585611105e-05 which came from a learning rate of 40
